# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from cascade_driver import CascadeDriver
cas_driver = CascadeDriver(zenith_angle = 30)
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)
# Tabulate cross-section for pi0(111)
# Tabulate cross-section for K_L0(130)
# Tabulate cross-section for pi-(-211)
# Tabulate cross-section for pi+(211)
# Tabulate cross-section for K_S0(310)
# Tabulate cross-section for K-(-321)
# Tabulate cross-section for K+(321)
# Tabulate cross-section for D-(-411)
# Tabulate cross-section for D+(411)
# Tabulate cross-section for Dbar0(-421)
# Tabulate cross-section for D0(421)
# Tabulate cross-section for D_s-(-431)
# Tabulate cross-section for D_s+(431)
# Tabulate cross-section for nbar0(-2112)
# Tabulate cross-section for n0(2112)
# Tabulate cross-section for pbar-(-2212)
# Tabulate cross-section for p+(2212)
# Tabulate cross-section for Lambdabar0(-3122)
# Tabulate cross-section for Lambda0(3122)
#  +-----------------------------------------------------------------------+
#  |                                                                       |
#  |                       DPMJET-III version 19.1.5                       |
#  |                                                                       |
#  |                      (Last change:  16 Jan 2023)                      |
#  |                                                                       |
#  |            Authors:                                                   |
#  |                     Stefan Roesler     (CERN)                         |
#  |                     Anatoli Fedynitch (ASIoP)                         |
#  |                     Ralph Engel        (KIT)                          |
#  |                     Johannes Ranft     (Siegen Univ.)                 |
#  |                                                                       |
#  |        https://github.com/afedynitch/dpmjet                           |
#  |                                                                       |
#  +-----------------------------------------------------------------------+
#  | Contact: @github
#  +-----------------------------------------------------------------------+
#
#
#   ===================================================
#
#     ----        PHOJET  19.1.5       ----
#
#   ===================================================
#       Authors: Ralph Engel         (KIT)
#                Anatoli Fedynitch  (ASIoP)
#                Johannes Ranft      (Siegen Univ.)
#                Stefan Roesler      (CERN)
#   ---------------------------------------------------
#     bug reports, support and updates on:
#       https://github.com/afedynitch/dpmjet
#   ===================================================
#     Date: 2023/01/16
#     Revision: 19.1.5
#     Code with interface to PYTHIA 6.4.27
#   ===================================================

# %%
from tqdm import tqdm
# mceq_decaying_pdgs = [111, -211, 211]

# mceq_decaying_pdgs = [-11, 11, -12, 12, -14, 14, 16, 22,
#                         111, 130, -211, 211, 310,
#                         -321, 321, -2112, 2112, 
#                         -2212, 2212, -3122, 3122]

# mceq_decaying_pdgs = [111, 130, 310, -13, 13, -211, 211]
# mceq_decaying_pdgs = [111, 130, 310]

# mceq_decaying_pdgs = [-11, 11, -12, 12, -13, 13, -14, 14, 
#                       -16, 16, 22, 
#                         111, 130, -211, 211, 310, -321, 321, 
#                         -411, 411, -421, 421, -431, 431, 
#                         -2112, 2112, -2212, 2212, -3122, 3122
#                         ]


# cas_driver.simulation_parameters(pdg = 2212, energy = 1e2, xdepth = 0,
#                                  threshold_energy = 1e-6, stop_height = 5,
#                                  accumulate_runs = True, reset_ids = True,
#                                  mceq_decaying_pdgs = mceq_decaying_pdgs)

niter = 10000
for i in tqdm(range(niter), total = niter):
    cas_driver.run()
# Out:
#   2%|▏         | 171/10000 [00:02<02:05, 78.26it/s]
#      Error type 4 has occured after   158779 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   158779 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   158822 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   158822 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   5%|▍         | 461/10000 [00:05<01:39, 96.06it/s]
#      Error type 4 has occured after   160886 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#   5%|▌         | 513/10000 [00:06<01:39, 95.14it/s]
#      Error type 4 has occured after   161296 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   161296 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   7%|▋         | 666/10000 [00:07<01:36, 96.95it/s]
#      Error type 4 has occured after   162332 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   162332 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   7%|▋         | 716/10000 [00:08<01:42, 90.55it/s]
#      Error type 4 has occured after   162687 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   162687 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   162764 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   162764 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   162765 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   162765 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   162766 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   162767 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   162767 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   8%|▊         | 846/10000 [00:09<01:38, 93.22it/s]
#      Error type 4 has occured after   163678 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  15%|█▌        | 1548/10000 [00:17<01:35, 88.51it/s]
#      Error type 4 has occured after   169057 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   169057 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  17%|█▋        | 1738/10000 [00:19<01:26, 95.48it/s]
#      Error type 4 has occured after   170473 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  22%|██▏       | 2200/10000 [00:24<01:28, 87.94it/s]
#      Error type 4 has occured after   173965 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  24%|██▍       | 2413/10000 [00:26<01:44, 72.43it/s]
#      Error type 4 has occured after   175670 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   175670 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  35%|███▍      | 3490/10000 [00:39<01:28, 73.72it/s]
#      Error type 4 has occured after   183835 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  38%|███▊      | 3781/10000 [00:42<01:07, 91.65it/s]
#      Error type 4 has occured after   185975 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  42%|████▏     | 4218/10000 [00:47<01:01, 93.78it/s]
#      Error type 4 has occured after   189147 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  44%|████▎     | 4351/10000 [00:48<00:57, 97.94it/s]
#      Error type 4 has occured after   190080 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   190080 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  44%|████▍     | 4443/10000 [00:49<00:58, 95.28it/s]
#      Error type 4 has occured after   190751 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  49%|████▉     | 4938/10000 [00:55<00:52, 97.06it/s]
#      Error type 4 has occured after   194437 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   194437 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  52%|█████▏    | 5150/10000 [00:57<00:54, 89.57it/s]
#      Error type 4 has occured after   195962 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   195962 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  52%|█████▏    | 5235/10000 [00:58<00:51, 91.65it/s]
#      Error type 4 has occured after   196585 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  53%|█████▎    | 5275/10000 [00:58<00:49, 95.12it/s]
#      Error type 4 has occured after   196866 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   196867 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   196867 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   196868 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   196869 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   196870 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   196870 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   196871 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  55%|█████▌    | 5500/10000 [01:01<00:49, 91.67it/s]
#      Error type 4 has occured after   198551 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   198551 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  59%|█████▊    | 5868/10000 [01:05<00:44, 93.47it/s]
#      Error type 4 has occured after   201216 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   201216 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  60%|██████    | 6019/10000 [01:06<00:43, 92.49it/s]
#      Error type 4 has occured after   202382 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   202382 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  60%|██████    | 6038/10000 [01:06<00:45, 86.77it/s]
#      Error type 4 has occured after   202535 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   202535 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  65%|██████▍   | 6489/10000 [01:11<00:37, 92.57it/s]
#      Error type 4 has occured after   205790 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   205790 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  67%|██████▋   | 6704/10000 [01:14<00:36, 89.64it/s]
#      Error type 4 has occured after   207500 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  68%|██████▊   | 6754/10000 [01:14<00:34, 94.09it/s]
#      Error type 4 has occured after   207915 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  68%|██████▊   | 6836/10000 [01:15<00:34, 91.67it/s]
#      Error type 4 has occured after   208499 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   208499 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  72%|███████▏  | 7151/10000 [01:19<00:28, 99.69it/s]
#      Error type 4 has occured after   210807 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  75%|███████▍  | 7484/10000 [01:22<00:25, 97.03it/s]
#      Error type 4 has occured after   213195 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  77%|███████▋  | 7676/10000 [01:24<00:25, 89.87it/s]
#      Error type 4 has occured after   214704 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   214704 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   214705 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   214824 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  85%|████████▌ | 8543/10000 [01:33<00:15, 95.94it/s]
#      Error type 4 has occured after   221149 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   221149 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   221150 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  88%|████████▊ | 8819/10000 [01:36<00:12, 93.59it/s]
#      Error type 4 has occured after   223154 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   223154 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  91%|█████████ | 9122/10000 [01:40<00:09, 91.55it/s]
#      Error type 4 has occured after   225358 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  92%|█████████▏| 9152/10000 [01:40<00:10, 80.46it/s]
#      Error type 4 has occured after   225637 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   225637 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  94%|█████████▍| 9419/10000 [01:43<00:06, 87.73it/s]
#      Error type 4 has occured after   227698 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   227698 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after   227699 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   227699 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  98%|█████████▊| 9765/10000 [01:47<00:02, 89.09it/s]
#      Error type 4 has occured after   230270 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after   230379 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  99%|█████████▊| 9873/10000 [01:48<00:01, 85.14it/s]
#      Error type 4 has occured after   231113 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after   231113 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
# 100%|██████████| 10000/10000 [01:50<00:00, 90.54it/s]

# %%
from cascade_analysis import CascadeAnalysis

cascade_analysis = CascadeAnalysis(cas_driver)
cascade_analysis.print_stats()
cascade_analysis.search_for_parents()
# Out:
# Number of runs = 30000
# Initial state:
#   $p$(2212) with energy = 1.000e+02
#
# Final state:
#   Number of all particles in cascade = 6202029
#   Number of final particles = 4141473
#   Number of interactions = 185010
#   Number of decays = 1875546
#   Max number of generations = 12
#
#   Max xdepth = 1193.2842407419082
#   Exectution time = 337.21 s
#   Exectution time per run = 0.01 s
#   Size of cascade_driver object = 1564.51 Mb
#
# Energy conservation in cascade:
#   Initial energy = 1.00000e+02 GeV
#   Energy in final particles = 1.13354e+02 GeV
#   Relative loss(+)/gain(-) -1.335e-01
# All final ids are unique, min = 16, max = 6202028
# {2112, -2112, 130, 321, 3112, -211, -3312, 3122, 211, 310, -321}

# %%
# cascade_analysis.check_particle_existence()

# %%
cascade_analysis.plot_ptypes_dist(from_ = 1)
# Out:
# {22: 278875, 14: 209397, -14: 206204, -11: 94886, 11: 93282, 12: 93229, -12: 91610, 2212: 52966, 2112: 29139, -13: 27067, 13: 23874, 310: 3008, 130: 3006, 211: 66, -211: 48, -2212: 42, -2112: 37, -321: 1}

# %%
cascade_analysis.plot_ptypes_energy_dist(from_ = 0)
# Out:
#         22 : 0.34181
#         14 : 0.10129
#        -14 : 0.08757
#        -11 : 0.03617
#         12 : 0.03058
#         11 : 0.03370
#        -12 : 0.02813
#       2212 : 0.06447
#       2112 : 0.03470
#        -13 : 0.13518
#         13 : 0.10059
#       -211 : 0.00033
#        211 : 0.00056
#      -2112 : 0.00012
#        130 : 0.00004
#      -2212 : 0.00004
# Total energy = 0.9952952032220888

# %%
cascade_analysis.plot_energy()

# %%
cascade_analysis.plot_energy_list(pids = [-13, 13, -14, 14, -11, 11, 2212, 2112, -211, 211])

# %%
# %autoreload 2
from mceq_comparison import MCEQDistributions
import matplotlib.pylab as plt
mceq_noloss = MCEQDistributions(
                 energy = 1e2,
                 pdg_id = 2212,
                 theta_deg = 30,
                 slant_depth = 800,
                #  slant_depth = 635.9540964571235,
                 pname_tuples = [
                     ("mu", "mu+", "mu-"),
                     ("numu", "numu", "antinumu"),
                     ("nue", "nue", "antinue"),
                     ("pi", "pi+", "pi-")],
                 interaction_model = "DPMJET-III-19.1",
                 generic_losses_all_charged = False, 
                 enable_energy_loss = False, 
                 muon_helicity_dependence = False,
                 disable_decays = [],
                 density_model = ("CORSIKA", ("BK_USStd", None)))
                #  disable_decays = [-13, 13, -211, 211]
mceq_dist = mceq_noloss
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)

# %%
# %autoreload 2
mceq_loss = MCEQDistributions(
                 energy = 1e2,
                 pdg_id = 2212,
                 theta_deg = 30,
                #  slant_depth = 635.9540964571235,
                 slant_depth = 638,
                 pname_tuples = [
                     ("mu", "mu+", "mu-"),
                     ("numu", "numu", "antinumu"),
                     ("nue", "nue", "antinue"),
                     ("pi", "pi+", "pi-")],
                 interaction_model = "DPMJET-III-19.1",
                #  generic_losses_all_charged = False, 
                 enable_energy_loss = True, 
                 muon_helicity_dependence = True,
                 disable_decays = [],
                 density_model = ("CORSIKA", ("USStd", None)))
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)

# %%
mceq_loss_bk = MCEQDistributions(
                 energy = 1e2,
                 pdg_id = 2212,
                 theta_deg = 30,
                #  slant_depth = 635.9540964571235,
                 slant_depth = 638,
                 pname_tuples = [
                     ("mu", "mu+", "mu-"),
                     ("numu", "numu", "antinumu"),
                     ("nue", "nue", "antinue"),
                     ("pi", "pi+", "pi-")],
                 interaction_model = "DPMJET-III-19.1",
                #  generic_losses_all_charged = False, 
                 enable_energy_loss = True, 
                 muon_helicity_dependence = True,
                 disable_decays = [],
                 density_model = ("CORSIKA", ("BK_USStd", None)))
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)
# operands could not be broadcast together with shapes (51,) (0,) (51,)

# %%
cascade_analysis.search_for_parents()
# Out:
# {2112, -2112, 130, 321, 3112, -211, -3312, 3122, 211, 310, -321}

# %%
plt.rcParams["figure.dpi"] = 150

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, -12), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-211, 211), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')


plt.stairs(mceq_dist.flux["mu"], mceq_dist.e_bins, 
           label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["numu"], mceq_dist.e_bins, 
           label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["nue"], mceq_dist.e_bins, 
           label = r"$\bar{\nu}_{e} + {\nu}_{e}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["pi"], mceq_dist.e_bins, 
           label = r"$\bar{\pi}^{+} + {\pi}^{-}$ mceq", linestyle='--')

plt.xscale("log")
plt.xlim(1e-2, 2e2)
# plt.ylim(-0.01, 0.5)
plt.legend()
plt.grid()
# plt.savefig('temp.png', transparent=True)
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745
# Histogram of -12 with mass 0.0
# Histogram of -12 with mass 0.0
# Histogram of -14 with mass 0.0
# Histogram of 14 with mass 0.0
# Histogram of -211 with mass 0.13957039000000002
# Histogram of 211 with mass 0.13957039000000002

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')


plt.stairs(mceq_dist.flux["mu"], mceq_dist.e_bins, 
           label = r"${\mu}^{+} + {\mu}^{-}$ mceq no loss", linestyle='--')

# plt.stairs(mceq_loss.flux["mu"], mceq_loss.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq loss", linestyle='--')

plt.xscale("log")
plt.xlim(1e-2, 2e2)
plt.ylim(-0.01, 0.5)
plt.legend()
plt.grid()
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["mu"], bins, label = f"{label} cas/mceq", linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, 12), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')


# plt.stairs(mceq_dist.flux["mu"]/1.1, mceq_dist.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq no loss", linestyle='--')

# plt.stairs(mceq_loss.flux["mu"], mceq_loss.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq loss", linestyle='--')

plt.xscale("log")
plt.xlim(1e-2, 3e2)
# plt.xlim(4e-1, 3e2)
plt.ylim(0.8, 1.2)
plt.legend()
plt.grid()
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745
# Histogram of -12 with mass 0.0
# Histogram of 12 with mass 0.0
# Histogram of -14 with mass 0.0
# /tmp/ipykernel_2502636/3658963680.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["mu"], bins, label = f"{label} cas/mceq", linestyle='-')
# /tmp/ipykernel_2502636/3658963680.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')
# Histogram of 14 with mass 0.0
# /tmp/ipykernel_2502636/3658963680.py:8: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')

# %%
plt.plot(mceq_loss.e_grid, mceq_loss.flux["mu"], 
         label = r"${\mu}^{+} + {\mu}^{-}$ USStd", linestyle='--')

# plt.plot(mceq_loss_bk.e_grid, mceq_loss_bk.flux["mu"], 
#          label = r"${\mu}^{+} + {\mu}^{-}$ BK_USStd", linestyle='-')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp1.png', transparent=True)

# %%
plt.plot(mceq_loss.e_grid, mceq_loss_bk.flux["mu"]/mceq_loss.flux["mu"], 
         label = r"${\mu}^{+} + {\mu}^{-}$ (BK_USStd/USStd)", linestyle='--')

# plt.plot(mceq_loss_bk.e_grid, mceq_loss_bk.flux["mu"], 
#          label = r"${\mu}^{+} + {\mu}^{-}$ bk", linestyle='-')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
# plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp.png', transparent=True)

# %%
plt.plot(res_mceq.egrid, res_mceq.mu_spec[1], label = f"{res_mceq.mu_spec[2]}", linestyle='--')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp.png', transparent=True)

# %%
plt.plot(res_mceq.egrid, res_mceq.numu_spec[1], label = f"{res_mceq.numu_spec[2]} stairs", linestyle='--')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 2.5)
plt.legend()
plt.savefig('temp_line.png', transparent=True)

# %%
plt.xscale("log")
plt.xlim(1e-1, 1e2)
plt.ylim(0.8, 1.2)
plt.step(res_mceq.mu_spec[0], cascade_analysis.mu/res_mceq.mu_spec[1], 
         label = r"${\mu}^{+} + {\mu}^{-}$ casc/mceq", linestyle='-', color = 'red')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu/res_mceq.numu_spec[1], 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ casc/mceq", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue/res_mceq.nue_spec[1], 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ casc/mceq", linestyle='-', color = 'blue')
plt.step(res_mceq.mu_spec[0], res_mceq.nue_spec[1]/res_mceq.nue_spec[1], color = 'grey')
plt.legend()

# %%
plt.xscale("log")
# plt.yscale("log")
plt.step(res_mceq.mu_spec[0], res_mceq.mu_spec[1], 
         label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='--', color = 'red')
plt.step(res_mceq.mu_spec[0], cascade_analysis.mu, 
         label = r"${\mu}^{+} + {\mu}^{-}$ casc", linestyle='-', color = 'red')
plt.step(res_mceq.mu_spec[0], res_mceq.numu_spec[1], 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ mceq", linestyle=':', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ casc", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], res_mceq.nue_spec[1], 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ mceq", linestyle=':', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ casc", linestyle='-', color = 'blue')
# plt.step(res_mceq.numu_spec[0], res_mceq.numu_spec[1], label = res_mceq.numu_spec[2], linestyle='--')
# plt.step(res_mceq.nue_spec[0], res_mceq.nue_spec[1], label = res_mceq.nue_spec[2], linestyle='--')
plt.xlim(1e-1, 1e3)
# plt.ylim(0, 0.5)
plt.legend()

# %%
plt.xscale("log")
plt.yscale("log")
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu_from_mu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ from muons", linestyle='--', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu_from_other, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ from other", linestyle=':', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ total", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue_from_mu, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ from muons", linestyle='--', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue_from_other, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ from other", linestyle=':', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ total", linestyle='-', color = 'blue')
# plt.step(res_mceq.numu_spec[0], res_mceq.numu_spec[1], label = res_mceq.numu_spec[2], linestyle='--')
# plt.step(res_mceq.nue_spec[0], res_mceq.nue_spec[1], label = res_mceq.nue_spec[2], linestyle='--')
plt.xlim(1e-1, 1e3)
plt.legend()

# %%
from fluka_comparison.fluka_muon_data import fluka_en_dist

# %%
for name, value in fluka_en_dist().items():
    # plt.steps(value[0], value[1])
    plt.stairs(value[1], value[0], label = f"depth = {name}")
    en_bins = value[0]

gr, cnt = np.histogram(cascade_analysis.raw_muon_data[0], bins=en_bins)
gr = gr/cascade_analysis.raw_muon_data[1] 
print(cnt, gr)
plt.stairs(gr, cnt, label = "depth = 635.955, cas")
plt.legend()
plt.ylim(0, 2) 

# gr1, cnt = np.histogram(self.neutrinos_from_muons[muon_neut].energy, bins = nbins, range = xrange)
#         gr1 = gr1/runs_number
#         plt.step(mceq_egrid, gr1, lab
# Out:
# [1.  1.3 2.  2.5 4.  5. ] [0.169 0.403 0.283 0.603 0.301]
# (0.0, 2.0)

# %%
cascade_analysis.plot_xdepth_list(nbins = 100, pids = [-14, 14, 2212, -13, 13], 
                                  xrange = (0, 1012), per_run = True)

# %%
cascade_analysis.plot_xdepth_stop(nbins = 100, pids = [-14, 14, 2212, -13, 13, 22], #pids = None, 
                                  all_pids = True, 
                                  xrange = (0, 1168), per_run = False)

# %%
cascade_analysis.plot_height_list(pids = [22, -13, 13, -11, 11], all_pids=True)

# %%
cascade_analysis.digitize()

# %%
import matplotlib.pylab as plt
plt.semilogx(cascade_analysis.egrid, cascade_analysis.hist_dict[22][0][99])



len(cascade_analysis.hist_dict[22][0])
