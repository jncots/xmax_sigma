# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pylab as plt

# %%
from cascade.cascade_driver import CascadeDriver
cas_driver = CascadeDriver()
# Out:
#  +-----------------------------------------------------------------------+
#  |                                                                       |
#  |                       DPMJET-III version 19.1.5                       |
#  |                                                                       |
#  |                      (Last change:  16 Jan 2023)                      |
#  |                                                                       |
#  |            Authors:                                                   |
#  |                     Stefan Roesler     (CERN)                         |
#  |                     Anatoli Fedynitch (ASIoP)                         |
#  |                     Ralph Engel        (KIT)                          |
#  |                     Johannes Ranft     (Siegen Univ.)                 |
#  |                                                                       |
#  |        https://github.com/afedynitch/dpmjet                           |
#  |                                                                       |
#  +-----------------------------------------------------------------------+
#  | Contact: @github
#  +-----------------------------------------------------------------------+
#
#
#   ===================================================
#
#     ----        PHOJET  19.1.5       ----
#
#   ===================================================
#       Authors: Ralph Engel         (KIT)
#                Anatoli Fedynitch  (ASIoP)
#                Johannes Ranft      (Siegen Univ.)
#                Stefan Roesler      (CERN)
#   ---------------------------------------------------
#     bug reports, support and updates on:
#       https://github.com/afedynitch/dpmjet
#   ===================================================
#     Date: 2023/01/16
#     Revision: 19.1.5
#     Code with interface to PYTHIA 6.4.27
#   ===================================================

# %%
from tqdm import tqdm
# mceq_decaying_pdgs = [111, -211, 211]

# mceq_decaying_pdgs = [-11, 11, -12, 12, -14, 14, 16, 22,
#                         111, 130, -211, 211, 310,
#                         -321, 321, -2112, 2112, 
#                         -2212, 2212, -3122, 3122]

# mceq_decaying_pdgs = [111, 130, 310, -13, 13, -211, 211]
# mceq_decaying_pdgs = [111, 130, 310]

# mceq_decaying_pdgs = [-11, 11, -12, 12, -14, 14, 
#                       -16, 16, 22, 
#                         111, 130, 310, -321, 321, 
#                         -411, 411, -421, 421, -431, 431, 
#                         -2112, 2112, -2212, 2212, -3122, 3122
#                         ]

mceq_decaying_pdgs = [-11, 11, -12, 12, -13, 13, -14, 14, 
                      -16, 16, 22, 
                        111, 130, -211, 211, 310, -321, 321, 
                        -411, 411, -421, 421, -431, 431, 
                        -2112, 2112, -2212, 2212, -3122, 3122
                        ]


cas_driver.simulation_parameters(pdg = 2212, energy = 1e2, 
                                 zenith_angle = 80, xdepth = 0,
                                 threshold_energy = 1e-6, stop_height = 0,
                                 accumulate_runs = True, reset_ids = True,
                                 mceq_decaying_pdgs = mceq_decaying_pdgs)

niter = 10000
for i in tqdm(range(niter), total = niter):
    cas_driver.run()
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)
# Tabulate cross-section for pi0(111)
# Tabulate cross-section for K_L0(130)
# Tabulate cross-section for pi-(-211)
# Tabulate cross-section for pi+(211)
# Tabulate cross-section for K_S0(310)
# Tabulate cross-section for K-(-321)
# Tabulate cross-section for K+(321)
# Tabulate cross-section for D-(-411)
# Tabulate cross-section for D+(411)
# Tabulate cross-section for Dbar0(-421)
# Tabulate cross-section for D0(421)
# Tabulate cross-section for D_s-(-431)
# Tabulate cross-section for D_s+(431)
# Tabulate cross-section for nbar0(-2112)
# Tabulate cross-section for n0(2112)
# Tabulate cross-section for pbar-(-2212)
# Tabulate cross-section for p+(2212)
# Tabulate cross-section for Lambdabar0(-3122)
# Tabulate cross-section for Lambda0(3122)
# stop depth = 5765.48833175094
#   0%|          | 10/10000 [00:00<01:51, 89.92it/s]
#      Error type 4 has occured after     9244 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after     9245 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#   2%|▏         | 159/10000 [00:01<01:37, 100.68it/s]
#      Error type 4 has occured after    10161 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    10161 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   2%|▏         | 200/10000 [00:02<01:45, 92.58it/s]
#      Error type 4 has occured after    10482 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    10482 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   2%|▏         | 241/10000 [00:02<01:45, 92.59it/s]
#      Error type 4 has occured after    10766 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    10766 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   3%|▎         | 317/10000 [00:03<02:38, 61.10it/s]
#      Error type 4 has occured after    11356 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after    11357 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#   6%|▌         | 622/10000 [00:07<01:40, 93.63it/s]
#      Error type 4 has occured after    13485 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    13485 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after    13486 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    13486 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   7%|▋         | 740/10000 [00:08<01:50, 83.94it/s]
#      Error type 4 has occured after    14363 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    14363 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after    14364 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    14364 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after    14490 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    14490 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   8%|▊         | 802/10000 [00:09<01:35, 96.59it/s]
#      Error type 4 has occured after    14793 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    14793 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#   8%|▊         | 832/10000 [00:10<02:01, 75.30it/s]
#      Error type 4 has occured after    15044 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#   9%|▉         | 936/10000 [00:11<01:35, 94.69it/s]
#      Error type 4 has occured after    15720 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    15720 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  10%|▉         | 957/10000 [00:11<01:31, 99.06it/s]
#      Error type 4 has occured after    15880 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    15880 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  11%|█         | 1058/10000 [00:12<01:36, 92.47it/s]
#      Error type 4 has occured after    16669 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    16669 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  13%|█▎        | 1291/10000 [00:14<01:31, 94.80it/s]
#      Error type 4 has occured after    18315 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    18315 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  14%|█▍        | 1375/10000 [00:15<01:30, 95.23it/s]
#      Error type 4 has occured after    18935 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  16%|█▌        | 1607/10000 [00:18<01:52, 74.63it/s]
#      Error type 4 has occured after    20577 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    20577 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  17%|█▋        | 1684/10000 [00:19<01:32, 89.56it/s]
#      Error type 4 has occured after    21167 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  18%|█▊        | 1769/10000 [00:20<01:43, 79.75it/s]
#      Error type 4 has occured after    21727 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after    21741 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    21741 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after    21791 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  18%|█▊        | 1798/10000 [00:21<01:35, 85.95it/s]
#      Error type 4 has occured after    21993 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after    21994 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    21994 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#
#      Error type 4 has occured after    21995 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  19%|█▉        | 1884/10000 [00:22<01:48, 74.80it/s]
#      Error type 4 has occured after    22611 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  24%|██▍       | 2409/10000 [00:28<01:57, 64.54it/s]
#      Error type 4 has occured after    26439 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  24%|██▍       | 2438/10000 [00:28<01:34, 80.20it/s]
#      Error type 4 has occured after    26621 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after    26622 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 4 has occured after    26623 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  25%|██▍       | 2476/10000 [00:29<01:26, 86.97it/s]
#      Error type 4 has occured after    26908 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  27%|██▋       | 2696/10000 [00:31<01:24, 86.48it/s]
#      Error type 4 has occured after    28498 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  28%|██▊       | 2845/10000 [00:33<01:18, 90.60it/s]
#      Error type 4 has occured after    29526 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  30%|██▉       | 2954/10000 [00:34<01:17, 90.80it/s]
#      Error type 4 has occured after    30363 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  30%|██▉       | 2982/10000 [00:35<01:24, 82.87it/s]
#      Error type 4 has occured after    30604 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#
#      Error type 2 has occured after    30604 PYEXEC calls:
#      (PYINDF:) unphysical flavour combination
#  32%|███▏      | 3248/10000 [00:38<01:10, 95.51it/s]
#      Error type 4 has occured after    32447 PYEXEC calls:
#      (PYSTRF:) caught in infinite loop
#  33%|███▎      | 3278/10000 [00:38<01:19, 84.71it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 35
#      33 niter = 10000
#      34 for i in tqdm(range(niter), total = niter):
# ---> 35     cas_driver.run()
#
# File ~/xmax_sigma/flincpy/cascade/cascade_driver.py:134, in CascadeDriver.run(self)
#     132 self.filter_by_energy()
#     133 self.filter_by_slant_depth()
# --> 134 self.run_hadron_interactions()
#     135 if len(self.working_stack) == 0:
#     136     self.run_particle_decay()
#
# File ~/xmax_sigma/flincpy/cascade/cascade_driver.py:235, in CascadeDriver.run_hadron_interactions(self)
#     232 if len(self.inter_stack) == 0:
#     233     return
# --> 235 self.number_of_interactions += self.hadron_interaction.run_event_generator(
#     236                                             parents = self.inter_stack,
#     237                                             children = self.children_stack,
#     238                                             failed_parents = self.rejection_stack)
#     241 self.id_generator.generate_ids(self.children_stack.valid().id)
#     242 self.children_stack.valid().production_code[:] = 2
#
# File ~/xmax_sigma/flincpy/process/hadron_inter.py:49, in HadronInteraction.run_event_generator(self, parents, children, failed_parents)
#      44         pvalid.production_code[i] = 333
#      46     continue
# ---> 49 event = next(self.event_generator(1)).final_state()
#      50 # try:
#      51 #     event = next(self.event_generator(1)).final_state()
#      52 # except RuntimeError as er:
#    (...)
#      57     #       f" and energy = {self.event_generator.kinematics.elab}")
#      58     # print(self.event_generator.kinematics)
#      60 number_of_interactions += 1
#
# File ~/chromo/src/chromo/common.py:578, in MCRun.__call__(self, nevents)
#     576 for nev in self._composite_plan(nevents):
#     577     while nev > 0:
# --> 578         if self._generate():
#     579             nretries = 0
#     580             self.nevents += 1
#
# File ~/chromo/src/chromo/models/dpmjetIII.py:199, in DpmjetIIIRun._generate(self)
#     197 def _generate(self):
#     198     k = self.kinematics
# --> 199     reject = self._lib.dt_kkinc(
#     200         k.p1.A or 1,
#     201         k.p1.Z or 0,
#     202         k.p2.A or 1,
#     203         k.p2.Z or 0,
#     204         self._lib.idt_icihad(2212)
#     205         if (k.p1.A and k.p1.A > 1)
#     206         else self._lib.idt_icihad(k.p1),
#     207         k.elab,
#     208         kkmat=-1,
#     209     )
#     210     self._lib.dtevno.nevent += 1
#     211     return not reject
#
# KeyboardInterrupt:

# %%
from cascade.cascade_analysis import CascadeAnalysis

cascade_analysis = CascadeAnalysis(cas_driver)
cascade_analysis.print_stats()
# cascade_analysis.search_for_parents()
# Out:
# Number of runs = 10000
# Initial state:
#   $p$(2212) with energy = 1.000e+02
#
# Final state:
#   Number of all particles in cascade = 2064510
#   Number of final particles = 1378556
#   Number of interactions = 61673
#   Number of decays = 624280
#   Max number of generations = 12
#
#   Max xdepth = 1195.9290875457918
#   Exectution time = 206.97 s
#   Exectution time per run = 0.02 s
#   Size of cascade_driver object = 548.89 Mb
#
# Energy conservation in cascade:
#   Initial energy = 1.00000e+02 GeV
#   Energy in final particles = 1.13335e+02 GeV
#   Relative loss(+)/gain(-) -1.334e-01
# All final ids are unique, min = 4, max = 2064509

# %%
cascade_analysis.plot_ptypes_dist(from_ = 1)
# Out:
# {22: 279347, 14: 209721, -14: 206622, 11: 142257, -12: 140543, 2212: 127896, -11: 95856, 12: 94161, 2112: 28882, -13: 27353, 13: 24254, -2212: 1491, 211: 65, -211: 62, -2112: 41, 130: 4, 321: 1}

# %%
cascade_analysis.plot_ptypes_energy_dist(from_ = 1)
# Out:
#         22 : 0.20251
#         14 : 0.05279
#        -14 : 0.04420
#       2212 : 0.39524
#         11 : 0.01172
#        -12 : 0.00959
#        -11 : 0.01330
#         12 : 0.01071
#        -13 : 0.10481
#         13 : 0.08232
#       2112 : 0.09153
#      -2212 : 0.00593
#        211 : 0.00983
#       -211 : 0.00640
#      -2112 : 0.00536
#        130 : 0.00051
#        321 : 0.00029
#       -321 : 0.00004
# Total energy = 1.0470641108035308

# %%
cascade_analysis.plot_energy()
# Out:
# Min = 6.66e+05 eV, Max = 9.25e+10 eV

# %%
cascade_analysis.plot_energy_list(pids = [-11, 11, -12, 12, -13, 13, -14, 14, 
                                          -211, 211])

# %%
cascade_analysis.plot_energy_list(pids = [-11, 11, -13, 13])

# %%
# %autoreload 2
from mceq_comparison import MCEQDistributions
mceq_noloss = MCEQDistributions(
                 energy = 1e2,
                 pdg_id = 2212,
                 theta_deg = 30,
                #  slant_depth = 800,
                #  slant_depth = 635.9540964571235,
                #  slant_depth= 313.4599011471651,
                #  slant_depth=1193,
                #  slant_depth=2997,
                 slant_depth=638,
                 energy_range=(0.1, 1e4),
                 pname_tuples = [
                     ("mu", "mu+", "mu-"),
                     ("numu", "numu", "antinumu"),
                     ("nue", "nue", "antinue"),
                     ("pi", "pi+", "pi-"),
                     ("el", "e+", "e-"),
                     ("e+", "e+"),
                     ("e-", "e-")],
                 interaction_model = "DPMJET-III-19.1",
                 generic_losses_all_charged = False, 
                 enable_energy_loss = False, 
                 muon_helicity_dependence = False,
                 disable_decays = [],
                 hybrid_crossover=0.01,
                 density_model = ("CORSIKA", ("BK_USStd", None)))
                #  disable_decays = [-13, 13, -211, 211]
mceq_dist = mceq_noloss
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('BK_USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)

# %%
mceq_dist.e_bins
# Out:
# array([7.94328235e-02, 1.00000000e-01, 1.25892541e-01, 1.58489319e-01,
#        1.99526231e-01, 2.51188643e-01, 3.16227766e-01, 3.98107171e-01,
#        5.01187234e-01, 6.30957344e-01, 7.94328235e-01, 1.00000000e+00,
#        1.25892541e+00, 1.58489319e+00, 1.99526231e+00, 2.51188643e+00,
#        3.16227766e+00, 3.98107171e+00, 5.01187234e+00, 6.30957344e+00,
#        7.94328235e+00, 1.00000000e+01, 1.25892541e+01, 1.58489319e+01,
#        1.99526231e+01, 2.51188643e+01, 3.16227766e+01, 3.98107171e+01,
#        5.01187234e+01, 6.30957344e+01, 7.94328235e+01, 1.00000000e+02,
#        1.25892541e+02, 1.58489319e+02, 1.99526231e+02, 2.51188643e+02,
#        3.16227766e+02, 3.98107171e+02, 5.01187234e+02, 6.30957344e+02,
#        7.94328235e+02, 1.00000000e+03, 1.25892541e+03, 1.58489319e+03,
#        1.99526231e+03, 2.51188643e+03, 3.16227766e+03, 3.98107171e+03,
#        5.01187234e+03, 6.30957344e+03, 7.94328235e+03, 1.00000000e+04])

# %%
cascade_analysis.search_for_parents()

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, -12), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-211, 211), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (111,), bins = mceq_dist.e_bins)
# plt.stairs(hist, bins, label = label, linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-11, 11), bins = mceq_dist.e_bins)
# plt.stairs(hist, bins, label = label, linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-11,), bins = mceq_dist.e_bins)
# plt.stairs(hist, bins, label = label, linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (11,), bins = mceq_dist.e_bins)
# plt.stairs(hist, bins, label = label, linestyle='-')

plt.stairs(mceq_dist.flux["mu"], mceq_dist.e_bins, 
           label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["numu"], mceq_dist.e_bins, 
           label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["nue"], mceq_dist.e_bins, 
           label = r"$\bar{\nu}_{e} + {\nu}_{e}$ mceq", linestyle='--')
plt.stairs(mceq_dist.flux["pi"], mceq_dist.e_bins, 
           label = r"$\bar{\pi}^{+} + {\pi}^{-}$ mceq", linestyle='--')

# plt.stairs(mceq_dist.flux["el"], mceq_dist.e_bins, 
#            label = r"$\bar{e}^{+} + {e}^{-}$ mceq", linestyle='--')

# plt.stairs(mceq_dist.flux["e+"], mceq_dist.e_bins, 
#            label = r"${e}^{+}$ mceq", linestyle='--')

# plt.stairs(mceq_dist.flux["e-"], mceq_dist.e_bins, 
#            label = r"${e}^{-}$ mceq", linestyle='--')

plt.xscale("log")
plt.xlim(1e-3, 2e2)
# plt.ylim(-0.01, 0.5)
plt.legend()
plt.grid()
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745
# Histogram of -12 with mass 0.0
# Histogram of -12 with mass 0.0
# Histogram of -14 with mass 0.0
# Histogram of 14 with mass 0.0
# Histogram of -211 with mass 0.13957039000000002
# Histogram of 211 with mass 0.13957039000000002

# %%
mceq_dist.e_bins
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mceq_dist.e_bins
#
# NameError: name 'mceq_dist' is not defined

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')


plt.stairs(mceq_dist.flux["mu"], mceq_dist.e_bins, 
           label = r"${\mu}^{+} + {\mu}^{-}$ mceq no loss", linestyle='--')

# plt.stairs(mceq_loss.flux["mu"], mceq_loss.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq loss", linestyle='--')

plt.xscale("log")
plt.xlim(1e-2, 2e2)
plt.ylim(-0.01, 0.45)
plt.legend()
plt.grid()
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-211, 211), bins = mceq_dist.e_bins)
plt.stairs(hist, bins, label = label, linestyle='-')


plt.stairs(mceq_dist.flux["pi"], mceq_dist.e_bins, 
           label = r"${\pi}^{+} + {\pi}^{-}$ mceq no loss", linestyle='--')

# plt.stairs(mceq_loss.flux["mu"], mceq_loss.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq loss", linestyle='--')

plt.xscale("log")
# plt.xlim(1e-2, 2e2)
# plt.ylim(-0.01, 0.5)
plt.legend()
plt.grid()
# Out:
# Histogram of -211 with mass 0.13957039000000002
# Histogram of 211 with mass 0.13957039000000002

# %%
bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-13, 13), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["mu"], bins, label = f"{label} cas/mceq", linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, 12), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')

bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')


# plt.stairs(mceq_dist.flux["mu"]/1.1, mceq_dist.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq no loss", linestyle='--')

# plt.stairs(mceq_loss.flux["mu"], mceq_loss.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq loss", linestyle='--')

plt.xscale("log")
plt.xlim(1e-2, 3e2)
# plt.xlim(4e-1, 3e2)
plt.ylim(0.8, 1.2)
plt.legend()
plt.grid()
# Out:
# Histogram of -13 with mass 0.1056583745
# Histogram of 13 with mass 0.1056583745
# Histogram of -12 with mass 0.0
# Histogram of 12 with mass 0.0
# Histogram of -14 with mass 0.0
# Histogram of 14 with mass 0.0
# /tmp/ipykernel_3082053/3658963680.py:2: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["mu"], bins, label = f"{label} cas/mceq", linestyle='-')
# /tmp/ipykernel_3082053/3658963680.py:5: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')
# /tmp/ipykernel_3082053/3658963680.py:8: RuntimeWarning: invalid value encountered in divide
#   plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')

# %%
from mceq_comparison import MCEQDistributions
mceq_corsika = MCEQDistributions(
                 energy = 1e2,
                 pdg_id = 2212,
                 theta_deg = 30,
                 slant_depth=1195.0,
                 energy_range = (3e-2, 1e4),
                 pname_tuples = [
                     ("mu", "mu+", "mu-"),
                     ("numu", "numu", "antinumu"),
                     ("nue", "nue", "antinue"),
                     ("pi", "pi+", "pi-"),
                     ("el", "e+", "e-"),
                     ("e+", "e+"),
                     ("e-", "e-")],
                 interaction_model = "DPMJET-III-19.1",
                 generic_losses_all_charged = True, 
                 enable_energy_loss = True, 
                 muon_helicity_dependence = True,
                 disable_decays = [],
                 hybrid_crossover=0.01,
                 density_model = ("CORSIKA", ("USStd", None)))
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)
# MCEqRun::set_density_model(): Setting density profile to CORSIKA ('USStd', None)
# MCEqRun::set_primary_model(): Primary model set to Hillas-Gaisser (H3a)

# %%
from scripts.corsika_comparison.corsika_comparison import corsika_hist, combined_data

# %%
en_hist = corsika_hist(mceq_corsika.e_bins)

# %%
plt.rcParams["figure.dpi"] = 150

# for i in range(4):
#     ixdepth = i
#     cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
#     plt.stairs(*cdata[0:2], label = cdata[2])

ixdepth = 3
cors_hist = dict()
for pdg in [12, 13, 14]:
    cors_hist[pdg] = combined_data(en_hist, (-pdg, pdg), ixdepth)
    plt.stairs(*cors_hist[pdg][0:2], label = f"{cors_hist[pdg][2]}, corsika", linestyle='--')

# pdg = 13    
# cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# ixdepth = 1
# pdg = 12
# cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# ixdepth = 1
# pdg = 14
# cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])


plt.stairs(mceq_corsika.flux["nue"], mceq_corsika.e_bins, 
           label = r"$\bar{\nu}_{e} + {\nu}_{e}$ mceq", linestyle='-')
    
plt.stairs(mceq_corsika.flux["mu"], mceq_corsika.e_bins, 
           label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='-')

plt.stairs(mceq_corsika.flux["numu"], mceq_corsika.e_bins, 
           label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ mceq", linestyle='-')
# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, 12), bins = mceq_dist.e_bins)
# plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
# plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')    

# ixdepth = 1
# cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# cdata = combined_data(en_hist, (-pdg,), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# cdata = combined_data(en_hist, (pdg,), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

plt.title(f"Slant depth, {cors_hist[13][3]}")
plt.xlabel(r"$E_{kin}$, GeV")
plt.ylabel("N, particles/bin/shower")
plt.xscale("log")
plt.xlim(5e-2, 1e2)
plt.ylim(0, 1e-5)
plt.legend()

# %%
ixdepth = 3
cors_hist = dict()
for pdg in [12, 13, 14]:
    cors_hist[pdg] = combined_data(en_hist, (-pdg, pdg), ixdepth)
    
plt.stairs(cors_hist[13][0]/mceq_corsika.flux["mu"], mceq_corsika.e_bins, 
           label = f"{cors_hist[13][2]} corsika/mceq", linestyle='-')

plt.stairs(cors_hist[12][0]/mceq_corsika.flux["nue"], mceq_corsika.e_bins, 
           label = f"{cors_hist[12][2]} corsika/mceq", linestyle='-')

plt.stairs(cors_hist[14][0]/mceq_corsika.flux["numu"], mceq_corsika.e_bins, 
           label = f"{cors_hist[14][2]} corsika/mceq", linestyle='-')

# plt.stairs(mceq_corsika.flux["numu"], mceq_corsika.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='-')

# plt.stairs(mceq_corsika.flux["nue"], mceq_corsika.e_bins, 
#            label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='-')
# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-12, 12), bins = mceq_dist.e_bins)
# plt.stairs(hist/mceq_dist.flux["nue"], bins, label = f"{label} cas/mceq", linestyle='-')

# bins, hist, label = cascade_analysis.kin_energy_histogram(pdgs = (-14, 14), bins = mceq_dist.e_bins)
# plt.stairs(hist/mceq_dist.flux["numu"], bins, label = f"{label} cas/mceq", linestyle='-')    

# ixdepth = 1
# cdata = combined_data(en_hist, (-pdg, pdg), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# cdata = combined_data(en_hist, (-pdg,), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

# cdata = combined_data(en_hist, (pdg,), ixdepth)
# plt.stairs(*cdata[0:2], label = cdata[2])

plt.xlabel(r"$E_{kin}$, GeV")
plt.ylabel("corsika/mceq count")
plt.xscale("log")
plt.xlim(1e-1, 1e2)
plt.ylim(0.8, 1.2)
plt.grid()
plt.legend()

# %%
plt.plot(mceq_loss.e_grid, mceq_loss.flux["mu"], 
         label = r"${\mu}^{+} + {\mu}^{-}$ USStd", linestyle='--')

# plt.plot(mceq_loss_bk.e_grid, mceq_loss_bk.flux["mu"], 
#          label = r"${\mu}^{+} + {\mu}^{-}$ BK_USStd", linestyle='-')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp1.png', transparent=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.plot(mceq_loss.e_grid, mceq_loss.flux["mu"],
#       2          label = r"${\mu}^{+} + {\mu}^{-}$ USStd", linestyle='--')
#       4 # plt.plot(mceq_loss_bk.e_grid, mceq_loss_bk.flux["mu"],
#       5 #          label = r"${\mu}^{+} + {\mu}^{-}$ BK_USStd", linestyle='-')
#       7 plt.xscale("log")
#
# NameError: name 'mceq_loss' is not defined

# %%
plt.plot(mceq_loss.e_grid, mceq_loss_bk.flux["mu"]/mceq_loss.flux["mu"], 
         label = r"${\mu}^{+} + {\mu}^{-}$ (BK_USStd/USStd)", linestyle='--')

# plt.plot(mceq_loss_bk.e_grid, mceq_loss_bk.flux["mu"], 
#          label = r"${\mu}^{+} + {\mu}^{-}$ bk", linestyle='-')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
# plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp.png', transparent=True)

# %%
plt.plot(res_mceq.egrid, res_mceq.mu_spec[1], label = f"{res_mceq.mu_spec[2]}", linestyle='--')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 0.31)
plt.legend()
plt.savefig('temp.png', transparent=True)

# %%
plt.plot(res_mceq.egrid, res_mceq.numu_spec[1], label = f"{res_mceq.numu_spec[2]} stairs", linestyle='--')

plt.xscale("log")
plt.xlim(4e-1, 2e2)
plt.ylim(-0.01, 2.5)
plt.legend()
plt.savefig('temp_line.png', transparent=True)

# %%
plt.xscale("log")
plt.xlim(1e-1, 1e2)
plt.ylim(0.8, 1.2)
plt.step(res_mceq.mu_spec[0], cascade_analysis.mu/res_mceq.mu_spec[1], 
         label = r"${\mu}^{+} + {\mu}^{-}$ casc/mceq", linestyle='-', color = 'red')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu/res_mceq.numu_spec[1], 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ casc/mceq", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue/res_mceq.nue_spec[1], 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ casc/mceq", linestyle='-', color = 'blue')
plt.step(res_mceq.mu_spec[0], res_mceq.nue_spec[1]/res_mceq.nue_spec[1], color = 'grey')
plt.legend()

# %%
plt.xscale("log")
# plt.yscale("log")
plt.step(res_mceq.mu_spec[0], res_mceq.mu_spec[1], 
         label = r"${\mu}^{+} + {\mu}^{-}$ mceq", linestyle='--', color = 'red')
plt.step(res_mceq.mu_spec[0], cascade_analysis.mu, 
         label = r"${\mu}^{+} + {\mu}^{-}$ casc", linestyle='-', color = 'red')
plt.step(res_mceq.mu_spec[0], res_mceq.numu_spec[1], 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ mceq", linestyle=':', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ casc", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], res_mceq.nue_spec[1], 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ mceq", linestyle=':', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ casc", linestyle='-', color = 'blue')
# plt.step(res_mceq.numu_spec[0], res_mceq.numu_spec[1], label = res_mceq.numu_spec[2], linestyle='--')
# plt.step(res_mceq.nue_spec[0], res_mceq.nue_spec[1], label = res_mceq.nue_spec[2], linestyle='--')
plt.xlim(1e-1, 1e3)
# plt.ylim(0, 0.5)
plt.legend()

# %%
plt.xscale("log")
plt.yscale("log")
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu_from_mu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ from muons", linestyle='--', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu_from_other, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ from other", linestyle=':', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.numu, 
         label = r"$\bar{\nu}_{\mu} + {\nu}_{\mu}$ total", linestyle='-', color = 'green')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue_from_mu, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ from muons", linestyle='--', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue_from_other, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ from other", linestyle=':', color = 'blue')
plt.step(res_mceq.mu_spec[0], cascade_analysis.nue, 
         label = r"$\bar{\nu}_{e} + {\nu}_{e}$ total", linestyle='-', color = 'blue')
# plt.step(res_mceq.numu_spec[0], res_mceq.numu_spec[1], label = res_mceq.numu_spec[2], linestyle='--')
# plt.step(res_mceq.nue_spec[0], res_mceq.nue_spec[1], label = res_mceq.nue_spec[2], linestyle='--')
plt.xlim(1e-1, 1e3)
plt.legend()

# %%
from fluka_comparison.fluka_muon_data import fluka_en_dist

# %%
for name, value in fluka_en_dist().items():
    # plt.steps(value[0], value[1])
    plt.stairs(value[1], value[0], label = f"depth = {name}")
    en_bins = value[0]

gr, cnt = np.histogram(cascade_analysis.raw_muon_data[0], bins=en_bins)
gr = gr/cascade_analysis.raw_muon_data[1] 
print(cnt, gr)
plt.stairs(gr, cnt, label = "depth = 635.955, cas")
plt.legend()
plt.ylim(0, 2) 

# gr1, cnt = np.histogram(self.neutrinos_from_muons[muon_neut].energy, bins = nbins, range = xrange)
#         gr1 = gr1/runs_number
#         plt.step(mceq_egrid, gr1, lab

# %%
cascade_analysis.plot_xdepth_list(nbins = 100, pids = [-14, 14, 2212, -13, 13], 
                                  xrange = (0, 1012), per_run = True)

# %%
cascade_analysis.plot_xdepth_stop(nbins = 100, pids = [-14, 14, 2212, -13, 13, 22], #pids = None, 
                                  all_pids = True, 
                                  xrange = (0, 1168), per_run = False)

# %%
cascade_analysis.plot_height_list(pids = [22, -13, 13, -11, 11], all_pids=True)

# %%
cascade_analysis.digitize()

# %%
import matplotlib.pylab as plt
plt.semilogx(cascade_analysis.egrid, cascade_analysis.hist_dict[22][0][99])



len(cascade_analysis.hist_dict[22][0])
