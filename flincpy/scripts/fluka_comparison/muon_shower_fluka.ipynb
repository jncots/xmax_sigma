# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pylab as plt
from muon_shower_fluka import muon_shower_data

# %%
muon_data = muon_shower_data()

# %%
plotted_data = muon_data["mu"]
for spect_data in plotted_data:
    plt.stairs(spect_data.val, spect_data.en_bins, 
               label = f"X={spect_data.xdepth} " + r"$\mathrm{g}/\mathrm{cm}^2$")


plt.title(plotted_data[0].particle_latex_name)    
plt.xscale("log")
# plt.xlim(0.3, 1e3)
plt.yscale("log")
plt.legend(fontsize = 8)    
plt.xlabel("E, GeV")
plt.ylabel("Flux")
# plt.grid(which="both")
plt.grid()
