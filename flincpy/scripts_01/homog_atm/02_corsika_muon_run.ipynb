# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pylab as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
params = {"mathtext.default": "regular",
          "text.usetex": False,
          "figure.dpi": 150}          
plt.rcParams.update(params)

# %%
from pathlib import Path

corsika_data_file = "muon_spectrum/02_muon_spectrum"
corsika_data_file = f"{corsika_data_file}/02_sp_muon_run.h5"

dir_for_figures = Path("/hetghome/antonpr/xmax_sigma/flincpy/scripts/")
dir_for_figures = dir_for_figures/"plots/muon_sp/20_muon_run"

# Create path if it doesn't exist
Path(dir_for_figures).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Corsika intializatioin

# %%
import sys
sys.path.append("/hetghome/antonpr/xmax_sigma/flincpy/scripts/corsika_flincpy")
from corsika_comparison import (corsika_hist_en, combined_data_en, 
                                 corsika_en_theta_2dhist,
                                 combined_ang_data)

# %%
# Corsika energy distributions
energy_bins = np.geomspace(1e-1, 1e3, 300)
# energy_bins = mceq.e_bins
chist_en = corsika_hist_en(energy_bins, 
                           h5file=corsika_data_file)
corsika_en_dist = {}
corsika_en_dist_mue = {}
corsika_en_dist_munu = {}

for i in range(3):
    corsika_en_dist[i]  = combined_data_en(chist_en, [-13, 13], i)
    corsika_en_dist_mue[i]  = combined_data_en(chist_en, [-12, 12], i)
    corsika_en_dist_munu[i]  = combined_data_en(chist_en, [-14, 14], i)
# Out:
# 02_sp_muon_run.h5: Number of primaries = 4.989000e+07
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 11
#       8 corsika_en_dist_munu = {}
#      10 for i in range(3):
# ---> 11     corsika_en_dist[i]  = combined_data_en(chist_en, [-13, 13], i)
#      12     corsika_en_dist_mue[i]  = combined_data_en(chist_en, [-12, 12], i)
#      13     corsika_en_dist_munu[i]  = combined_data_en(chist_en, [-14, 14], i)
#
# File ~/xmax_sigma/flincpy/scripts/corsika_flincpy/corsika_comparison.py:81, in combined_data_en(energy_hist, pdgs, ixdepth)
#      78 label_p = f"{label[1:]}"
#      79 label_x = f"X={energy_hist[pdg][0][ixdepth][2]}"
# ---> 81 return (hist/energy_hist[pdg][0][ixdepth][3],
#      82         energy_hist[pdg][0][ixdepth][1],
#      83         label_p, label_x,
#      84         energy_hist[pdg][0][ixdepth][3], # num_primaries
#      85         )
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/miniconda3/envs/env_impy/lib/python3.9/site-packages/h5py/_hl/dataset.py:1046, in Dataset.__array__(self, dtype)
#    1043 if numpy.product(self.shape, dtype=numpy.ulonglong) == 0:
#    1044     return arr
# -> 1046 self.read_direct(arr)
#    1047 return arr
#
# File ~/miniconda3/envs/env_impy/lib/python3.9/site-packages/h5py/_hl/dataset.py:1007, in Dataset.read_direct(self, dest, source_sel, dest_sel)
#    1004     dest_sel = sel.select(dest.shape, dest_sel)
#    1006 for mspace in dest_sel.broadcast(source_sel.array_shape):
# -> 1007     self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:192, in h5py.h5d.DatasetID.read()
#
# File h5py/_proxy.pyx:108, in h5py._proxy.dset_rw()
#
# ValueError: Invalid dataset identifier (invalid dataset identifier)

# %%
# Corsika angular distributions
# energy_bins = [1, 1.25892541, 1.99526231,  2.51188643,  3.98107171, 5.01187234]
energy_bins_ang = [1, 1.3, 2, 2.5, 4, 5]
# ang_bins = fluka_ang_bins
ang_bins = np.deg2rad(np.linspace(0, 30, 61))
corsika_en_hist = corsika_en_theta_2dhist(energy_bins_ang, 
                                          ang_bins,
                                          h5file=corsika_data_file)

corsika_comb_mu = combined_ang_data(corsika_en_hist, (-13, 13))
corsika_comb_nue = combined_ang_data(corsika_en_hist, (-12, 12))
corsika_comb_numu = combined_ang_data(corsika_en_hist, (-14, 14))
# Out:
# pdg = -12
# xdepth=1000.0, number=4.3379e+07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 # ang_bins = fluka_ang_bins
#       5 ang_bins = np.deg2rad(np.linspace(0, 30, 61))
# ----> 6 corsika_en_hist = corsika_en_theta_2dhist(energy_bins_ang,
#       7                                           ang_bins,
#       8                                           h5file=corsika_data_file)
#      10 corsika_comb_mu = combined_ang_data(corsika_en_hist, (-13, 13))
#      11 corsika_comb_nue = combined_ang_data(corsika_en_hist, (-12, 12))
#
# File ~/xmax_sigma/flincpy/scripts/corsika_flincpy/corsika_comparison.py:97, in corsika_en_theta_2dhist(en_bins, theta_bins, h5file)
#      95 for i, xdepth in enumerate(xdepth_list):
#      96     mc_energy = np.array(corsika_data[str(pdg)][str(ix[i])]["energy [GeV]"])
# ---> 97     mc_theta = np.array(corsika_data[str(pdg)][str(ix[i])]["theta [rad]"])
#      98     print(f"xdepth={xdepth}, number={len(mc_energy)*1e0:.4e}")
#     100     # If Omega is used for binning
#     101     # mc_omega = 2*np.pi*(1 - np.cos(mc_theta))
#     102     # mc_theta = mc_omega
#
# KeyboardInterrupt:

# %%
figure_name = "fig_cc_01.svg"
figure = plt.figure(figsize=(17, 5))
grid_spec = figure.add_gridspec(nrows=1, 
                                ncols=3, 
                                width_ratios=[1, 1, 1])

axis = []
for i in range(1):
    axis_row = []
    for j in range(3):
        axis_row.append(figure.add_subplot(grid_spec[i, j]))
    axis.append(axis_row)

ixdepth = 2
xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = axis[0][0]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
# Corsika0    
# for ixdepth in range(3):    
#     fl_hist_en = corsika_en_dist0[ixdepth]
#     ax.stairs(fl_hist_en[0], fl_hist_en[1], 
#                     label = f"Corsika_MFalse, {fl_hist_en[3]} " + r"$g/cm^2$",
#                     color = line_colors[ixdepth],
#                     linestyle = "--")
    
ax.set_title(r"$\mu^{+} + \mu^{-}$")

ax.set_xscale("log")
ax.set_xlim(1e-1, 1e3)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# ax.set_ylim(0, 0.032)
ax.legend(fontsize="8")
ax.grid()          

# Muon mu
ax = axis[0][1]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_munu[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
# Corsika0    
# for ixdepth in range(3):    
#     fl_hist_en = corsika_en_dist0[ixdepth]
#     ax.stairs(fl_hist_en[0], fl_hist_en[1], 
#                     label = f"Corsika_MFalse, {fl_hist_en[3]} " + r"$g/cm^2$",
#                     color = line_colors[ixdepth],
#                     linestyle = "--")
    
ax.set_title(r"$\nu_{\mu} + \bar\nu_{\mu}$")

ax.set_xscale("log")
ax.set_xlim(1e-1, 1e3)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# ax.set_ylim(0, 0.032)
ax.legend(fontsize="8")
ax.grid()   

# Muon e
ax = axis[0][2]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_mue[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
# Corsika0    
# for ixdepth in range(3):    
#     fl_hist_en = corsika_en_dist0[ixdepth]
#     ax.stairs(fl_hist_en[0], fl_hist_en[1], 
#                     label = f"Corsika_MFalse, {fl_hist_en[3]} " + r"$g/cm^2$",
#                     color = line_colors[ixdepth],
#                     linestyle = "--")
    
ax.set_title(r"$\nu_e + \bar\nu_e$")

ax.set_xscale("log")
ax.set_xlim(1e-1, 1e3)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# ax.set_ylim(0, 0.032)
ax.legend(fontsize="8")
ax.grid()   



figure.suptitle(r"Corsika energy distribution, Primary"  + 
            r"$\mu^{-}$, $E_{kin}=100$ GeV, $\theta=0^{\circ}$")

figure.tight_layout()   
plt.savefig(dir_for_figures/figure_name)

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
sys.path.insert(1,
                os.path.abspath('/hetghome/antonpr/MCEq'))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import mceq_config as config
from MCEq.core import MCEqRun
from MCEq.geometry.density_profiles import GeneralizedTarget
import matplotlib.pyplot as plt

# %%
config.debug_level = 1
config.max_density = 1.293e-3 #0.001225
config.e_min = 1e-1
config.muon_helicity_dependence = False
config.average_loss_operator = False
config.enable_2D = False
config.mceq_db_fname = "/hetghome/antonpr/MCEq/MCEq/data/mceq_db_lext_dpm191_v150.h5"

# %%
target_grammage = 10000 # g/cm2
target = GeneralizedTarget(len_target=target_grammage/config.max_density, 
                           env_density=config.max_density, 
                           env_name='homogeneous air')

# %%
mceq = MCEqRun(interaction_model="DPMJETIII191", 
               theta_deg=None, 
               density_model=target, 
               primary_model=None)
# Out:
# MCEqRun::set_interaction_model(): DPMJETIII191
# ParticleManager::_init_default_tracking(): Initializing default tracking categories (pi, K, mu)

# %%
print(f"Target max_X={target.max_X}," 
      f"target length={target.len_target/1e2:.2f} m")
# Out:
# Target max_X=10000.0,target length=77339.52 m

# %%
from normalized_spectrum import NormalizedSpectrum
from normalized_spectrum import HistFromDist

muon_spectr = NormalizedSpectrum(pdg_id = 13,
                                 etot_min = 0.01, etot_max = 1000, 
                                 spectral_index = 3,
                                 number_particle_norm = 1)
# Out:
# /hetghome/antonpr/xmax_sigma/flincpy/scripts_01/homog_atm/normalized_spectrum.py:26: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt((etot - mass)*(etot + mass))

# %%
muon_init_spectrum = muon_spectr.dN_dekin(mceq.e_grid)
mceq.set_initial_spectrum(muon_init_spectrum, 
                          pdg_id=13, append=False)

mceq_xdepths = [0, 1000, 5000, 10000]
mceq.solve(int_grid=mceq_xdepths)

# %%
mceq_sol = {}
particle_groups = [(13, "mu+", "mu-"),
                    (14, "numu", "antinumu"),
                    (12, "nue", "antinue"),
                    (211, "pi+", "pi-"),
                    (11, "e+", "e-")]

for pdg, *group in particle_groups:
    
    dist_xdepth = {}
    for ixdepth in range(len(mceq_xdepths)):
        dist = None
        for particle in group:
            if dist is None:
                dist = mceq.get_solution(particle, grid_idx = ixdepth)
            else:
                dist += mceq.get_solution(particle, grid_idx = ixdepth)
        dist_xdepth[ixdepth] = dist
    
    mceq_sol[pdg] = dist_xdepth

# %%
mceq_sol_hist = {}
for pdg in mceq_sol:
    xdepth_hist = {}
    for ixdepth in mceq_sol[pdg]:
        hist = HistFromDist(mceq.e_grid, mceq_sol[pdg][ixdepth])
        bins, dN = hist.hist(energy_bins)
        xdepth_hist[ixdepth] = dN
    mceq_sol_hist[pdg] = xdepth_hist

# %%
for ixdepth in range(len(xdepths)):
    plt.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
               label = f"X = {xdepths[ixdepth]}")
plt.xscale("log")
plt.yscale("log")
plt.xlim(1e-1, 1e3)
plt.ylim(1e-9, 1e1)
plt.legend()

# %%
xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    
    fl_hist_en = corsika_en_dist[ixdepth]
    error_cors = np.sqrt(fl_hist_en[0]/4.989000e+07)
    
    # heights+0.5, edges, baseline=heights-0.5, fill=True, alpha=0.2
    
    line = ax.stairs(fl_hist_en[0]-error_cors, fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    # print(fl_hist_en[0]-error_cors)
    # line = ax.stairs(fl_hist_en[0]+error_cors, fl_hist_en[1], 
    #                 baseline = fl_hist_en[0]-error_cors, 
    #                 fill=True,
    #                 alpha = 0.2, 
    #                 # label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
    #                 color = line_colors[ixdepth],
    #                 linestyle = "-")
    # error_cors = np.sqrt(fl_hist_en[0]/4.989000e+07)
    # plt.errorbar((energy_bins[:-1] + energy_bins[1:])/2, 
    #                      fl_hist_en[0],
    #                      color=line.get_edgecolor(), 
    #                      yerr=error_cors,
    #                      linestyle='', capsize=5)
    
    # plt.fill_between((energy_bins[:-1] + energy_bins[1:])/2, 
    #                          fl_hist_en[0]-error_cors, 
    #                          fl_hist_en[0]+error_cors,
    #                          alpha=0.5, 
    #                          edgecolor='#CC4F1B', 
    #                          facecolor='#FF9848')
    
# for ixdepth in range(len(mceq_xdepths)):
#     ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
#                label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
-08 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 4.00881940e-08 1.17415602e-08
#  1.17415602e-08 0.00000000e+00 5.54005216e-08 0.00000000e+00
#  1.17415602e-08 1.17415602e-08 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00]

# %%
figure_name = "fig_muon_01.svg"
figure = plt.figure(figsize=(17, 5))
grid_spec = figure.add_gridspec(nrows=1, 
                                ncols=3, 
                                width_ratios=[1, 1, 1])

axis = []
for i in range(1):
    axis_row = []
    for j in range(3):
        axis_row.append(figure.add_subplot(grid_spec[i, j]))
    axis.append(axis_row)

ixdepth = 2
xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = axis[0][0]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
    
for ixdepth in range(len(mceq_xdepths)):
    ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
               label = f"mceq X = {mceq_xdepths[ixdepth]}",
               color = line_colors[ixdepth - 1],
               linestyle = "--")    
    
ax.set_title(r"$\mu^{+} + \mu^{-}$")

ax.set_xscale("log")
ax.set_xlim(1e-2, 1e3)
ax.set_ylim(1e-8, 1e1)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()          

# Muon mu
ax = axis[0][1]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_munu[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")

for ixdepth in range(len(mceq_xdepths)):
    ax.stairs(mceq_sol_hist[14][ixdepth], energy_bins, 
               label = f"mceq X = {mceq_xdepths[ixdepth]}",
               color = line_colors[ixdepth - 1],
               linestyle = "--")      
    
    
ax.set_title(r"$\nu_{\mu} + \bar\nu_{\mu}$")

ax.set_xscale("log")
ax.set_xlim(1e-1, 1e3)
ax.set_ylim(1e-8, 1e1)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()   

# Muon e
ax = axis[0][2]
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_mue[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
for ixdepth in range(len(mceq_xdepths)):
    ax.stairs(mceq_sol_hist[12][ixdepth], energy_bins, 
               label = f"mceq X = {mceq_xdepths[ixdepth]}",
               color = line_colors[ixdepth - 1],
               linestyle = "--")     
    
ax.set_title(r"$\nu_e + \bar\nu_e$")

ax.set_xscale("log")
ax.set_xlim(1e-1, 1e3)
ax.set_ylim(1e-10, 1e1)
ax.set_xlabel("E, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()   



figure.suptitle(r"Corsika energy distribution, Primary"  + 
            r"$\mu^{-}$, $dN/dE=1/E^{-3}$ GeV, $\theta=0^{\circ}$")

figure.tight_layout()   
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig_muon_01_01.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
    
for ixdepth in range(len(mceq_xdepths)):
    ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
               label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
               color = line_colors[ixdepth - 1],
               linestyle = "--")

ax.set_title(r"$\mu^{+} + \mu^{-}$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(1e-8, 1e1)
ax.set_xlabel(r"$E$, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig_muon_01_01_rat.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist[ixdepth]
    line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[13][ixdepth + 1], fl_hist_en[1], 
                    label = f"Corsika/MCEq, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
    
# for ixdepth in range(len(mceq_xdepths)):
#     ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
#                label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
#                color = line_colors[ixdepth - 1],
#                linestyle = "--")

ax.set_title("Ratio Corsika/MCEq, " + r"$\mu^{+} + \mu^{-}$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(0, 3)
ax.set_xlabel(r"$E$, GeV")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)
# Out:
# /tmp/ipykernel_1592659/2796895871.py:11: RuntimeWarning: divide by zero encountered in divide
#   line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[13][ixdepth + 1], fl_hist_en[1],
# /tmp/ipykernel_1592659/2796895871.py:11: RuntimeWarning: invalid value encountered in divide
#   line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[13][ixdepth + 1], fl_hist_en[1],

# %%
figure_name = "fig_muon_01_02.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_munu[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
for ixdepth in range(len(mceq_xdepths)):
    if ixdepth == 0:
        continue
    ax.stairs(mceq_sol_hist[14][ixdepth], energy_bins, 
               label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
               color = line_colors[ixdepth - 1],
               linestyle = "--")     
    
ax.set_title(r"$\nu_{\mu} + \bar\nu_{\mu}$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(1e-8, 1e0)
ax.set_xlabel(r"$E$, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig_muon_01_02_rat.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_munu[ixdepth]
    line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[14][ixdepth + 1], fl_hist_en[1], 
                    label = f"Corsika/MCEq, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
    
# for ixdepth in range(len(mceq_xdepths)):
#     ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
#                label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
#                color = line_colors[ixdepth - 1],
#                linestyle = "--")

ax.set_title("Ration Corsika/MCEq, " + r"$\nu_{\mu} + \bar\nu_{\mu}$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(0, 7)
ax.set_xlabel(r"$E$, GeV")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)
# Out:
# /tmp/ipykernel_1592659/2998265142.py:11: RuntimeWarning: invalid value encountered in divide
#   line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[14][ixdepth + 1], fl_hist_en[1],

# %%
figure_name = "fig_muon_01_03.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_mue[ixdepth]
    line = ax.stairs(fl_hist_en[0], fl_hist_en[1], 
                    label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
for ixdepth in range(len(mceq_xdepths)):
    if ixdepth == 0:
        continue
    ax.stairs(mceq_sol_hist[12][ixdepth], energy_bins, 
               label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
               color = line_colors[ixdepth - 1],
               linestyle = "--")     
    
ax.set_title(r"$\nu_e + \bar\nu_e$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(1e-8, 1e0)
ax.set_xlabel(r"$E$, GeV")

ax.set_yscale("log")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig_muon_01_03_rat.svg"

xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


ax = plt.gca()
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist_mue[ixdepth]
    line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[12][ixdepth + 1], fl_hist_en[1], 
                    label = f"Corsika/MCEq, {fl_hist_en[3]} " + r"$g/cm^2$",
                    color = line_colors[ixdepth],
                    linestyle = "-")
    
    
# for ixdepth in range(len(mceq_xdepths)):
#     ax.stairs(mceq_sol_hist[13][ixdepth], energy_bins, 
#                label = f"MCEq, X = {mceq_xdepths[ixdepth]} " + r"$g/cm^2$",
#                color = line_colors[ixdepth - 1],
#                linestyle = "--")

ax.set_title("Ration Corsika/MCEq, " + r"$\nu_e + \bar\nu_e$")

ax.set_xscale("log")
ax.set_xlim(8e-2, 2e3)
ax.set_ylim(0, 7)
ax.set_xlabel(r"$E$, GeV")
ax.set_ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
ax.legend(fontsize="8")
ax.grid()
plt.savefig(dir_for_figures/figure_name)
# Out:
# /tmp/ipykernel_1438525/3081473416.py:11: RuntimeWarning: invalid value encountered in divide
#   line = ax.stairs(fl_hist_en[0]/mceq_sol_hist[12][ixdepth + 1], fl_hist_en[1],

# %%
dEdX = (np.trapz(mceq.get_solution("mu-", mag=0) * mceq.e_grid, mceq.e_grid)/np.trapz(mceq.get_solution("mu-", mag=0), mceq.e_grid) - Emu)/target.max_X
print(dEdX)
plt.plot(mceq.e_grid, mceq.get_solution("mu-", mag=0)* mceq.e_grid)
plt.plot(mceq.e_grid, muon_sp_grid * mceq.e_grid)
plt.xscale("log")
plt.xlim(1e0, 1e5)
plt.yscale("log")
plt.ylim(1e-6)

# %%
HistFromDist()

# %% [markdown]
# # Corsika_MTrue vs Corsika_MFalse angular distributions

# %%
figure_name = "fig_cc_02.svg"

figure = plt.figure(figsize=(17, 15))
grid_spec = figure.add_gridspec(nrows=3, 
                                ncols=3, 
                                width_ratios=[1, 1, 1], 
                                height_ratios=[1, 1, 1])

axis = []
for i in range(3):
    axis_row = []
    for j in range(3):
        axis_row.append(figure.add_subplot(grid_spec[i, j]))
    axis.append(axis_row)

ixdepth = 2
xdepths = [143, 647, 1033]
line_colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
en_labels = ["1.0-1.3", "2.0-2.5", "4.0-5.0"]


for ixdepth in range(3):
  ax = axis[0][ixdepth] 
  
  icolor = 0
  ienlabel = 0  
  for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
      if i in [0, 2, 4]: # Choose energy ranges to plot
          ax.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                            label = f"Corsika_MTrue {en_labels[ienlabel]} GeV",
                            color = line_colors[icolor],
                            linestyle = "-"
                          )
          icolor += 1
          ienlabel += 1  

  icolor = 0
  ienlabel = 0        
  for i, crs_comb_mu in enumerate(corsika_comb_mu0[ixdepth]):
      if i in [0, 2, 4]: # Choose energy ranges to plot
          ax.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                            label = f"Corsika_MFalse {en_labels[ienlabel]} GeV",
                            color = line_colors[icolor],
                            linestyle = "--"
                          ) 
          icolor += 1
          ienlabel += 1
          
  ax.set_title(f"X={xdepths[ixdepth]}" + r"$g/cm^2$")

  ax.set_xlabel(r"$\theta$, deg")
  ax.set_ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
  # plt.yscale("log")
  # plt.xlim(0.08, 0.1)
  ax.set_ylim(0, 0.032)
  ax.legend(fontsize="10")
  ax.grid()

# Log
for ixdepth in range(3):
  ax = axis[1][ixdepth] 
  
  icolor = 0
  ienlabel = 0  
  for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
      if i in [0, 2, 4]: # Choose energy ranges to plot
          ax.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                            label = f"Corsika_MTrue {en_labels[ienlabel]} GeV",
                            color = line_colors[icolor],
                            linestyle = "-"
                          )
          icolor += 1
          ienlabel += 1  

  icolor = 0
  ienlabel = 0        
  for i, crs_comb_mu in enumerate(corsika_comb_mu0[ixdepth]):
      if i in [0, 2, 4]: # Choose energy ranges to plot
          ax.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                            label = f"Corsika_MFalse {en_labels[ienlabel]} GeV",
                            color = line_colors[icolor],
                            linestyle = "--"
                          ) 
          icolor += 1
          ienlabel += 1
          
  ax.set_title(f"X={xdepths[ixdepth]}" + r"$g/cm^2$")

  ax.set_xlabel(r"$\theta$, deg")
  ax.set_ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
  ax.set_yscale("log")
  # plt.xlim(0.08, 0.1)
  ax.set_ylim(1e-7, 0.032)
  ax.legend(fontsize="10")
  ax.grid()

# Ratio
for ixdepth in range(3):
  ax = axis[2][ixdepth]

  icolor = 0
  ienlabel = 0
  for i, _ in enumerate(corsika_comb_mu[ixdepth]):
      if i in [0, 2, 4]: # Choose energy ranges to plot
          
          crs_comb_mu = corsika_comb_mu[ixdepth][i]
          crs_comb_mu0 = corsika_comb_mu0[ixdepth][i]
          ax.stairs(crs_comb_mu[0]/crs_comb_mu0[0], np.rad2deg(crs_comb_mu[1]), 
                            label = f"Corsika_MTrue/Corsika_MFalse {en_labels[ienlabel]} GeV",
                            color = line_colors[icolor],
                            linestyle = "-"
                          )
          icolor += 1
          ienlabel += 1  
          
          
  ax.set_title(f"X={xdepths[ixdepth]}" + r"$g/cm^2$")

  ax.set_xlabel(r"$\theta$, deg")
  ax.set_ylabel(r"Corsika_MTrue/Corsika_MFalse")
  # plt.yscale("log")
  # plt.xlim(0.08, 0.1)
  ax.set_ylim(0, 2)
  ax.legend(fontsize="10")  
  ax.grid()                 
  
figure.suptitle(r"Corsika_MTrue vs. Corsika_MFalse, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
            r"$E_{0}=100$ GeV, $\theta=30^{\circ}$")  
figure.tight_layout()
plt.savefig(dir_for_figures/figure_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 27
#      25 icolor = 0
#      26 ienlabel = 0
# ---> 27 for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
#      28     if i in [0, 2, 4]: # Choose energy ranges to plot
#      29         ax.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]),
#      30                           label = f"Corsika_MTrue {en_labels[ienlabel]} GeV",
#      31                           color = line_colors[icolor],
#      32                           linestyle = "-"
#      33                         )
#
# NameError: name 'corsika_comb_mu' is not defined

# %%
# for xdepth in [143, 647, 1033]:
#     plt.stairs(mceq_hists[13][xdepth]["hist_en_ang"].T[0],
#                 mceq_hists[13][xdepth]["en_bins"], label = f"MCEq, X={xdepth}")
xdepth_list = [143, 647, 1033]

line_colors = []
for ixdepth in range(3):
    
    line = plt.stairs(mceq_hists_en[13][xdepth_list[ixdepth]]["hist_en_ang"].T[0],
            mceq_hists_en[13][xdepth_list[ixdepth]]["en_bins"], 
            label = f"MCEq2D, X={xdepth_list[ixdepth]} " + r"$g/cm^2$",
            # color = line.get_edgecolor(),
                #   linestyle = "--"
                    )
    line_colors.append(line.get_edgecolor())
    
for ixdepth in range(3):    
    fl_hist_en = fluka_hist_en["current"][ixdepth]
    plt.stairs(fl_hist_en[1], fl_hist_en[0], 
                      label = f"Fluka, X={fl_hist_en[3]} " + r"$g/cm^2$",
                      color = line_colors[ixdepth],
                      linestyle = "--")


# Corsika
for ixdepth in range(3):    
    fl_hist_en = corsika_en_dist[ixdepth]
    plt.stairs(fl_hist_en[0], fl_hist_en[1], 
                      label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
                      color = line_colors[ixdepth],
                      linestyle = ":")
    
    # fl_hist_en = corsika_en_dist[ixdepth]
    # plt.stairs(fl_hist_en[0], fl_hist_en[1], 
    #                   label = f"corsika {fl_hist_en[3]} g/cm2",
    #                   color = line.get_edgecolor(),
    #                   linestyle = ":"
    #                   )

plt.xscale("log")
plt.xlim(1e-1, 1e2)
plt.yscale("log")
plt.xlabel("E, GeV")
plt.ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
plt.legend(fontsize="8")   
plt.title(r"MCEq2D vs. Fluka(2021) vs. Corsika, $\mu_{-} + \mu_{+}$ energy spectra" + "\n"
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$")
plt.savefig(dir_for_figures/'fig01_02.png')

# %%
xdepth_list = [143, 647, 1033]

line_colors = []

# Fluka
for ixdepth in range(3):
  cr_hist_en = corsika_en_dist[ixdepth]
  fl_hist_en = fluka_hist_en["current"][ixdepth]
  line = plt.stairs(fl_hist_en[1]/cr_hist_en[0],
              fl_hist_en[0], 
              label = f"Fluka/Corsika, X={xdepth_list[ixdepth]} " + r"$g/cm^2$")
  
  line_colors.append(line.get_edgecolor())
  
# Corsika
# for ixdepth in range(3):    
#     fl_hist_en = corsika_en_dist[ixdepth]
#     plt.stairs(fl_hist_en[0], fl_hist_en[1], 
#                       label = f"Corsika, {fl_hist_en[3]} " + r"$g/cm^2$",
#                       color = line_colors[ixdepth],
#                       linestyle = "--")

plt.xscale("log")
plt.xlim(3e-1, 1e2)
plt.ylim(0.75, 1.5)
# plt.yscale("log")
plt.xlabel("E, GeV")
plt.ylabel(r"$\frac{dN}{dE}\Delta E$ per primary")
plt.legend(fontsize="8")   
plt.title(r"Ratio of Fluka/Corsika of $\mu_{-} + \mu_{+}$ energy spectra" + "\n"
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$")
plt.grid()
plt.savefig(dir_for_figures/'fig01_03.png')

# %% [markdown]
# # Anglular distributions

# %%
# Get MCEq histogram
angle_bins = fluka_ang_bins
energy_bins = [1, 1.3, 2, 2.5, 4, 5]
mceq_hists_ang = mceq_dists.histograms(energy_bins, angle_bins)

# %%
xdepth = 143
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/'fig10.png')

# %%
xdepth = 143
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/'fig11.png')

# %%
xdepth = 143
ixdepth = 0
line_colors = []
ienergy = 0
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Fluka/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
# for ixdepth in range(3):
#     for ienergy in range(3):
#         if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
#             fl_dist = fluka_hist["current"][ixdepth][ienergy]
#             line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
#                     label = f"current: {fl_dist[4]} GeV",
#                     color = line_colors[ienergy],
#                     linestyle = "--")      
        
        
plt.title(r"Ratio Fluka/MCEq2D of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0.3, 1.2)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/'fig12.png')

# %%
xdepth = 647
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [1]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/'fig13.png')

# %%
xdepth = 647
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [1]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/'fig14.png')

# %%
figure_name = "fig15.png"
xdepth = 647
ixdepth = 1
line_colors = []
ienergy = 0
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Fluka/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
# for ixdepth in range(3):
#     for ienergy in range(3):
#         if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
#             fl_dist = fluka_hist["current"][ixdepth][ienergy]
#             line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
#                     label = f"current: {fl_dist[4]} GeV",
#                     color = line_colors[ienergy],
#                     linestyle = "--")      
        
        
plt.title(r"Ratio Fluka/MCEq2D of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0.1, 1.2)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig16.png"
xdepth = 1033
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [2]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig17.png"
xdepth = 1033
line_colors = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [2]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")      
        
        
plt.title(r"Fluka vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig18.png"
xdepth = 1033
ixdepth = 2
line_colors = []
ienergy = 0
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Fluka/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        
        
# for ixdepth in range(3):
#     for ienergy in range(3):
#         if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
#             fl_dist = fluka_hist["current"][ixdepth][ienergy]
#             line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
#                     label = f"current: {fl_dist[4]} GeV",
#                     color = line_colors[ienergy],
#                     linestyle = "--")      
        
        
plt.title(r"Ratio Fluka/MCEq2D of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0, 1.2)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/figure_name)

# %% [markdown]
# # Corsika vs Fluka

# %%
figure_name = "fig02_01.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_02.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_03.png"
xdepth = 143
ixdepth = 0
line_colors = []
ienergy = 0

for ind_energy, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/crs_comb_mu[0],
                    np.rad2deg(crs_comb_mu[1]),
                    label = f"Fluka/Corsika {en_label} GeV")
        line_colors.append(line.get_edgecolor())  
        
        
plt.title(r"Ratio Fluka/Corsika of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0, 1.5)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_04.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_05.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_06.png"
xdepth = 647
ixdepth = 1
line_colors = []
ienergy = 0

for ind_energy, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/crs_comb_mu[0],
                    np.rad2deg(crs_comb_mu[1]),
                    label = f"Fluka/Corsika {en_label} GeV")
        line_colors.append(line.get_edgecolor())  
        
        
plt.title(r"Ratio Fluka/Corsika of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0, 1.5)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_07.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_08.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        # line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
        #             np.rad2deg(mceq_plt["ang_bins"]),
        #             label = f"MCEq {en_label} GeV")
        # line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                        #   color = line_colors[icolor],
                        #   linestyle = "--"
                        )
        
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        icolor += 1
        ienlabel += 1  
        
for ixdepth in range(3):
    for ienergy in range(3):
        if (ienergy in [0, 1, 2]) and (ixdepth in [0]):
            fl_dist = fluka_hist["current"][ixdepth][ienergy]
            line = plt.stairs(fl_dist[1], np.rad2deg(fl_dist[0]),
                    label = f"Fluka {fl_dist[4]} GeV",
                    color = line_colors[ienergy],
                    linestyle = "--")          
          
        
        
plt.title(r"Corsika vs. Fluka, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig02_09.png"
xdepth = 1033
ixdepth = 2
line_colors = []
ienergy = 0

for ind_energy, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        
        fl_dist = fluka_hist["current"][ixdepth][ienergy]
        ienergy += 1
        line = plt.stairs(fl_dist[1]/crs_comb_mu[0],
                    np.rad2deg(crs_comb_mu[1]),
                    label = f"Fluka/Corsika {en_label} GeV")
        line_colors.append(line.get_edgecolor())  
        
        
plt.title(r"Ratio Fluka/Corsika of $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Fluka/MCEq")
# plt.yscale("log")
plt.xlim(0, 20)
plt.ylim(0, 1.5)
plt.grid()
plt.legend(fontsize="8", loc = "best")  
plt.savefig(dir_for_figures/figure_name)

# %% [markdown]
# # Corsika vs MCEq with fluka bins

# %%
figure_name = "fig19.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig20.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig21.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig22.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig23.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig24.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig25.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig26.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig27.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_en[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
# plt.xlim(0.08, 0.1)
# plt.ylim(20, 25)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %% [markdown]
# # Corsika vs MCEq2D

# %%
# Get MCEq histogram
# angle_bins = fluka_ang_bins
angle_bins = np.deg2rad(np.linspace(0, 90, 91))
energy_bins = [1, 1.3, 2, 2.5, 4, 5]
mceq_hists_ang1 = mceq_dists.histograms(energy_bins, angle_bins)

# %%
energy_bins = [1, 1.3, 2, 2.5, 4, 5]
angle_bins = np.deg2rad(np.linspace(0, 90, 91))
corsika_en_hist1 = corsika_en_theta_2dhist(energy_bins, 
                                          angle_bins,
                                          h5file=corsika_data_file)

corsika_comb_mu1 = combined_ang_data(corsika_en_hist1, (-13, 13))
corsika_comb_nue1 = combined_ang_data(corsika_en_hist1, (-12, 12))
corsika_comb_numu1 = combined_ang_data(corsika_en_hist1, (-14, 14))

# %%
figure_name = "fig28.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig29.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig30.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu1[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
plt.xlim(0, 30)
plt.ylim(0, 3)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig31.png"
xdepth = 143
ixdepth = 0
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu1[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
plt.xlim(0, 30)
plt.ylim(0.5, 1.2)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig32.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig33.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig34.png"
xdepth = 647
ixdepth = 1
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu1[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
plt.xlim(0, 30)
plt.ylim(0, 1.5)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig35.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
# plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig36.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)

icolor = 0
ienlabel = 0
for i, crs_comb_mu in enumerate(corsika_comb_mu1[ixdepth]):
    if i in [0, 2, 4]: # Choose energy ranges to plot
        line = plt.stairs(crs_comb_mu[0], np.rad2deg(crs_comb_mu[1]), 
                          label = f"Corsika {en_labels[ienlabel]} GeV",
                          color = line_colors[icolor],
                          linestyle = "--")
        icolor += 1
        ienlabel += 1  
          
        
        
plt.title(r"Corsika vs. MCEq2D, $\mu_{-} + \mu_{+}$ angular distribution" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"$\frac{dN}{dEd\Omega}\Delta E\Delta \Omega$ per primary")
plt.yscale("log")
plt.xlim(0, 30)
# plt.ylim(20, 25)
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)

# %%
figure_name = "fig37.png"
xdepth = 1033
ixdepth = 2
line_colors = []
en_labels = []
for ind_energy, en1 in enumerate(mceq_hists_ang1[13][xdepth]["en_bins"]):
    if ind_energy in [0, 2, 4]:
        mceq_plt = mceq_hists_ang1[13][xdepth]
        en_range = mceq_plt["en_bins"][ind_energy:ind_energy +2]
        en_label = f"{en_range[0]:0.1f}-{en_range[1]:0.1f}"
        line = plt.stairs(corsika_comb_mu1[ixdepth][ind_energy][0]/mceq_plt["hist_en_ang"][ind_energy],
                    np.rad2deg(mceq_plt["ang_bins"]),
                    label = f"Corsika/MCEq {en_label} GeV")
        line_colors.append(line.get_edgecolor())
        en_labels.append(en_label)
        
        
plt.title(r"Ratio of Corsika/MCEq2D, $\mu_{-} + \mu_{+}$ angular distributions" + "\n" +
          r"$E_{0}=100$ GeV, $\theta=30^{\circ}$" + f", X={xdepth}" + r"$g/cm^2$")
plt.xlabel(r"$\theta$, deg")
plt.ylabel(r"Corsika/MCEq2D")
# plt.yscale("log")
plt.xlim(0, 30)
plt.ylim(0, 1.5)
plt.grid()
plt.legend(fontsize="8")  
plt.legend()
plt.savefig(dir_for_figures/figure_name)
