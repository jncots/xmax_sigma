# %%
from pyhank import HankelTransform
import scipy.special
import matplotlib.pyplot as plt

# %%
transformer = HankelTransform(order=0, max_radius=100, n_points=1024)
f = scipy.special.jv(1, transformer.r) / transformer.r

plt.figure()
plt.plot(transformer.r, f)
plt.xlabel('Radius /m')
# Out:
# Text(0.5, 0, 'Radius /m')

# %%
import time

# %%
start = time.time()
ht = transformer.qdht(f)
end = time.time()
print(end - start)
# Out:
# 0.0017671585083007812

# %%
ht = transformer.qdht(f)

plt.figure()
plt.plot(transformer.kr, ht)
plt.xlim([0, 5])
plt.xlabel('Radial wavevector /m$^{-1}$')
# Out:
# Text(0.5, 0, 'Radial wavevector /m$^{-1}$')

# %%
iht = transformer.iqdht(ht)
plt.figure()
plt.plot(transformer.r, iht)
# plt.xlim([0, 5])
plt.xlabel('Radial wavevector /m$^{-1}$')
# Out:
# Text(0.5, 0, 'Radial wavevector /m$^{-1}$')

# %%
import numpy as np

# create two numpy arrays
a = np.array([[1, 2], [3, 4], [5, 6]])
b = np.array([[2, 3], [4, 5], [6, 7]])



# print the result
print((a[:, None]*b[:, :,None])[:,1])
# Out:
# [[ 3  6]
#  [15 20]
#  [35 42]]

# %%
b[:, None]
# Out:
# array([[[2, 3]],
#
#        [[4, 5]],
#
#        [[6, 7]]])

# %%
a[:,:, None]
# Out:
# array([[[1],
#         [2]],
#
#        [[3],
#         [4]],
#
#        [[5],
#         [6]]])
